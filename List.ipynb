# %%
i=list()

# %%
print(i)
# Out:
# []

# %%
numbers= list(range(5))

# %%
numbers
# Out:
# [0, 1, 2, 3, 4]

# %%
letters=list("python")
letters
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
empty=list()
empty
# Out:
# []

# %% [markdown]
# #Nested List

# %%
Matrix=[["a","b","c"],["d","e","f"]]

# %%
Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f']]

# %%
type(Matrix)
# Out:
# list

# %%
Mixed_Matrix=[["a","b","c"],[1,2,3,4]]

# %%
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], [1, 2, 3, 4]]

# %%
Mixed_Matrix1=[["a","b","c"],[1,2,3,4],[True]]
Mixed_Matrix1
# Out:
# [['a', 'b', 'c'], [1, 2, 3, 4], [True]]

# %%
A=[1,3,4,4]
print(A)
# Out:
# [1, 3, 4, 4]

# %%
a=list(1,3,2)
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 a=list(1,3,2)
#       2 print(a)
#
# TypeError: list expected at most 1 argument, got 3

# %%
type(A)
type(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 type(A)
# ----> 2 type(a)
#
# NameError: name 'a' is not defined

# %%
A=[1,1.23,True,None,"Rajesh"]
print(A)
# Out:
# [1, 1.23, True, None, 'Rajesh']

# %% [markdown]
# #Access & Read

# %%
First=["a","b","c","d"]
First
# Out:
# ['a', 'b', 'c', 'd']

# %%
First[0]
# Out:
# 'a'

# %%
First[3]
# Out:
# 'd'

# %%
First[-3]
# Out:
# 'b'

# %%
First[0:-4]
# Out:
# []

# %% [markdown]
# #Access & Read Nested List

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2

Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h', 'i']]

# %%
Mixed_Matrix[-1]
# Out:
# ['g', 'h', 'i']

# %%
Mixed_Matrix[-1][-1]
# Out:
# 'i'

# %%
Mixed_Matrix[-1][-2]
# Out:
# 'h'

# %%
Mixed_Matrix[-2][-3]
# Out:
# 'd'

# %%
Mixed_Matrix[1][2]
# Out:
# 'f'

# %%
Mixed_Matrix[1][1]
# Out:
# 'e'

# %%
Mixed_Matrix[0][0]
# Out:
# 'a'

# %%
First=["a","b","c","d"]
First[:2]
# Out:
# ['a', 'b']

# %%
First[0:3]
# Out:
# ['a', 'b', 'c']

# %%
First[2:4]
# Out:
# ['c', 'd']

# %%
First[2:]
# Out:
# ['c', 'd']

# %%
First[-1]
# Out:
# 'd'

# %%
First[-4:-1]
# Out:
# ['a', 'b', 'c']

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2

Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h', 'i']]

# %%
Mixed_Matrix[2][0:2]
# Out:
# ['g', 'h']

# %%
Mixed_Matrix[0][1:3]
# Out:
# ['b', 'c']

# %% [markdown]
# #Packing & Unpacking

# %%
person_details=["Rajesh",29,"rrajeshkumar057@gmail.com","Sql Developer"]

#Name=person_details[0]
#Age=person_details[1]
#Email=person_details[2]
#Designation=person_details[3]

#Instead of using this technique use unpaking to unpack thos data. in real time we have N number of data so.

# %%
Name,Age,Email,Designation=person_details #unpacking is clean, easy way to extend out code.

# %%
Name
# Out:
# 'Rajesh'

# %%
Age
# Out:
# 29

# %%
Designation
# Out:
# 'Sql Developer'

# %% [markdown]
# #Rest Collector

# %%
person_details=[1,"Rajesh",29,"rrajeshkumar057@gmail.com","Sql Developer","01-02-1997"]

# %%
id,*details,dob=person_details1  #if you use *in front of input it return middle of data

# %%
id
# Out:
# 1

# %%
details
# Out:
# ['Rajesh', 29, 'rrajeshkumar057@gmail.com', 'Sql Developer']

# %%
dob
# Out:
# '01-02-1997'

# %%
person_details=[1,"Rajesh",29,"rrajeshkumar057@gmail.com","Sql Developer","01-02-1997"]

id,*details=person_details

# %%
details
# Out:
# ['Rajesh', 29, 'rrajeshkumar057@gmail.com', 'Sql Developer', '01-02-1997']

# %%
id
# Out:
# 1

# %%
person_details=[1,"Rajesh",29,"rrajeshkumar057@gmail.com","Sql Developer","01-02-1997"]

*details,dob=person_details

# %%
# Out:
# 1

# %%
dob
# Out:
# '01-02-1997'

# %%
details
# Out:
# [1, 'Rajesh', 29, 'rrajeshkumar057@gmail.com', 'Sql Developer']

# %%
person_details=[1,"Rajesh",29,"rrajeshkumar057@gmail.com","Sql Developer","01-02-1997"]

*details,designation,dob=person_details

# %%
details
# Out:
# [1, 'Rajesh', 29, 'rrajeshkumar057@gmail.com']

# %%
designation
# Out:
# 'Sql Developer'

# %%
dob
# Out:
# '01-02-1997'

# %% [markdown]
# #Rule of Asterisk allowed in unpacking

# %% [markdown]
# #Number of variable must be matching with a value

# %% [markdown]
# #You can unpacking any squence (list,tuple,distinory,string)

# %%
N=[1,2,3,4,5,6]

First,*rest=N

# %%
First
# Out:
# 1

# %%
rest
# Out:
# [2, 3, 4, 5, 6]

# %%
N=[1,2,3,4,5,6]

First,*middle,Last=N

# %%
middle
# Out:
# [2, 3, 4, 5]

# %%
person_details=[1,"Rajesh",29,"rrajeshkumar057@gmail.com","Sql Developer","01-02-1997"]

id,*_,dob=person_details

# %%
id
# Out:
# 1

# %%
dob
# Out:
# '01-02-1997'

# %%
a,b,c=[1,2,3]

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %% [markdown]
# #How to Explore and Analys Data:

# %%
numbers=[1,10,18,20,8,9]

print("minimun: ", min(numbers))
print("Maximun: ", max(numbers))
print("lenght: ", len(numbers))
print("Sum: ", sum(numbers))

#its all works on onlu numbers
# Out:
# minimun:  1
# Maximun:  20
# lenght:  6
# Sum:  66

# %%
nums = [1, 2, 0]

if all(nums):
    print("All values are True")
else:
    print("Some value is False")
# Out:
# Some value is False

# %%
numbers=[1,10,18,20,8,9]

print("all: ",all(numbers))
# Out:
# all:  True

# %%
print("all: ",all([1,2,3]))
# Out:
# all:  True

# %%
print("all: ",all([1,0,3]))
# Out:
# all:  False

# %%
print("all: ",all([1,"a","b"]))
# Out:
# all:  True

# %%
print("all: ",all([1,"","b"]))
# Out:
# all:  False

# %%
numbers=[1,10,18,20,8,9]

print("Any: ",any(numbers))
# Out:
# Any:  True

# %%
print("Any: ",any(["a",0,1]))
# Out:
# Any:  True

# %%
print("all: ",all([0,0]))
# Out:
# all:  False

# %%
numbers=[1,10,18,20,8,9,8,8]

print("Count: ",numbers.count(10))
# Out:
# Count:  1

# %%
print("Count: ",numbers.count(8))
# Out:
# Count:  3

# %%
print('index: ',numbers.index(10))
# Out:
# index:  1

# %%
print('index: ',numbers.index(20))   #index return position of the fisrt occurence
# Out:
# index:  3

# %%
list1=[1,2,3,4,5]

print("list: ", 8 in list1)
# Out:
# list:  False

# %%
print("list: ", 5 in list1)
# Out:
# list:  True

# %%
print("list: ", 8 not in list1)
# Out:
# list:  True

# %%
list1=[1,2,3,4,5]
list2=[1,2,3,4,5]


print(list1==list2)
# Out:
# True

# %% [markdown]
# #How to add, Remove and Update data:

# %% [markdown]
# #Append - its used to add new value to the end  of the list

# %%
letters=["a","b","c"]

# %%
letters.append("e")

# %%
letters
# Out:
# ['a', 'b', 'c', 'e', 'f']

# %%
letters.append("f")

# %%
letters
# Out:
# ['a', 'b', 'c', 'e', 'f']

# %% [markdown]
# #Insert -  insert will used to insert the values to the specific position like specific index

# %%
letters=["a","b","c"]

# %%
letters.insert(0,"x")

# %%
letters
# Out:
# ['x', 'a', 'b', 'c']

# %%
letters.insert(3,"y")

# %%
letters
# Out:
# ['x', 'a', 'b', 'y', 'c']

# %%
#Adding new row

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h', 'i']]

# %%
Mixed_Matrix.append(["x","y","z"])

# %%
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h', 'i'], ['x', 'y', 'z']]

# %%
Mixed_Matrix.insert(0,["R","S","T"])

# %% [markdown]
# Mixed_Matrix

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h', 'i']]

# %%
Mixed_Matrix[1].append("x")

# %%
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f', 'x', 'x', 'x'], ['g', 'h', 'i']]

# %%
Mixed_Matrix[0].insert(2,"y")

# %%
Mixed_Matrix
# Out:
# [['a', 'b', 'y', 'c'], ['d', 'e', 'f', 'x', 'x', 'x'], ['g', 'h', 'i']]

# %% [markdown]
# #Remove Data

# %% [markdown]
# #Clear- its hepl to remove everything

# %%
letters=["R","S","T"]

# %%
letters.clear()

# %%
letters
# Out:
# []

# %% [markdown]
# #remove- its help to remove data specific place and its removing first value of what u given

# %%
letters=["R","S","T","R"]

letters.remove("R")

# %%
letters
# Out:
# ['S', 'T', 'R']

# %% [markdown]
# #POP - this funtion will give Removing data and Returning data
#
# if you didnt mention any index on pop it will removes last data

# %%
letters=["R","S","T","R"]

Removed=letters.pop()

# %%
Removed
# Out:
# 'R'

# %%
letters
# Out:
# ['R', 'S', 'T']

# %%
letters=["R","S","T","R"]

Removed=letters.pop(1)

Removed
# Out:
# 'S'

# %%
print(f"Removed item: {Removed}")
# Out:
# Removed item: S

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2


Mixed_Matrix.remove(["g","h","i"])

# %%
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f']]

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2

Mixed_Matrix.pop()
# Out:
# ['g', 'h', 'i']

# %%
print(f"Removed item: {Mixed_Matrix}")
# Out:
# Removed item: [['a', 'b', 'c'], ['d', 'e', 'f']]

# %%
print(f"Return items: {Mixed_Matrix}")
# Out:
# Return items: [['a', 'b', 'c'], ['d', 'e', 'f']]

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2

Mixed_Matrix[1].pop()
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e'], ['g', 'h', 'i']]

# %%
Mixed_Matrix[0].pop(0)
# Out:
# 'a'

# %%
Mixed_Matrix[2].pop(1)
# Out:
# 'h'

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2


Mixed_Matrix[1].remove("f")

# %%
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e'], ['g', 'h', 'i']]

# %%
Mixed_Matrix.remove(['d', 'e'])
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['g', 'h', 'i']]

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2
Mixed_Matrix.pop(1)
# Out:
# ['d', 'e', 'f']

# %%
print(f"Return items: {Mixed_Matrix}")
# Out:
# Return items: [['a', 'b', 'c'], ['g', 'h', 'i']]

# %% [markdown]
# #Update -  update data

# %%
upd=["a","b","c"]

upd[1]="Y"
upd[0]="X"
upd[2]="Z"

# %%
upd
# Out:
# ['X', 'Y', 'Z']

# %%
upd="Q"
upd
# Out:
# 'Q'

# %%
type(upd)
# Out:
# str

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2
Mixed_Matrix[2][-1]="-"

# %%
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h', '-']]

# %%
Mixed_Matrix[1][-2]="-"
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', '-', 'f'], ['g', 'h', '-']]

# %%
Mixed_Matrix[0][1]="-"
Mixed_Matrix
# Out:
# [['a', '-', 'c'], ['d', '-', 'f'], ['g', 'h', '-']]

# %%
Mixed_Matrix[0][0]="-"
Mixed_Matrix
# Out:
# [['-', '-', 'c'], ['d', '-', 'f'], ['g', 'h', '-']]

# %%
Mixed_Matrix[0][1]="b"
Mixed_Matrix
# Out:
# [['-', 'b', 'c'], ['d', '-', 'f'], ['g', 'h', '-']]

# %% [markdown]
# ##How to sort or order data

# %% [markdown]
# #Sort() - this function return sorting data and if you didnt mention anything inside () it will assuming we will assk ascending order.
#
#
# #Sort.(reverse=True) - it make descending

# %%
name =["Rajesh","Kowsi","Rajaskar","Seetha","Sampath","Miranah"]

name.sort()

name
# Out:
# ['Kowsi', 'Miranah', 'Rajaskar', 'Rajesh', 'Sampath', 'Seetha']

# %%
name.sort(reverse=True)

# %%
name
# Out:
# ['Seetha', 'Sampath', 'Rajesh', 'Rajaskar', 'Miranah', 'Kowsi']

# %%
name =["Rajesh","Kowsi","Rajaskar","Seetha","Sampath","Miranah"]

name.sort(reverse=False)#ascending

name
# Out:
# ['Kowsi', 'Miranah', 'Rajaskar', 'Rajesh', 'Sampath', 'Seetha']

# %% [markdown]
# #Wheneve you using list inside list like nested list it will works like its sorting a data based on first letter of each list. if two list having same letter then it go to second on

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["g","h","i"]]   #row 2

Mixed_Matrix.sort()

# %%
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h', 'i']]

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["a","a","i"]]   #row 2

Mixed_Matrix.sort()

# %%
Mixed_Matrix
# Out:
# [['a', 'a', 'i'], ['a', 'b', 'c'], ['d', 'e', 'f']]

# %% [markdown]
# #if you mention index after the input name it sort based only that

# %%
Mixed_Matrix=[["a","b","c"],   #row 0
              ["d","e","f"],   #row 1
              ["a","a","i"]]   #row 2

Mixed_Matrix[1].sort(reverse=True)

# %%
Mixed_Matrix
# Out:
# [['a', 'b', 'c'], ['f', 'e', 'd'], ['a', 'a', 'i']]

# %% [markdown]
# #sorted -  it means it will make copy of data with sorting order

# %%
name =["Rajesh","Kowsi","Rajaskar","Seetha","Sampath","Miranah"]


new_list=sorted(name)
print("Original name ",name)
# Out:
# Original name  ['Rajesh', 'Kowsi', 'Rajaskar', 'Seetha', 'Sampath', 'Miranah']

# %%
print("Sorted name :" ,new_list)
# Out:
# Sorted name : ['Kowsi', 'Miranah', 'Rajaskar', 'Rajesh', 'Sampath', 'Seetha']

# %%
name =["Rajesh","Kowsi","Rajaskar","Seetha","Sampath","Miranah"]


new_list=sorted(name,reverse=True)
print("Original name ",name)
print("Sorted name :" ,new_list)
# Out:
# Original name  ['Rajesh', 'Kowsi', 'Rajaskar', 'Seetha', 'Sampath', 'Miranah']
# Sorted name : ['Seetha', 'Sampath', 'Rajesh', 'Rajaskar', 'Miranah', 'Kowsi']

# %% [markdown]
# #Reverse() - it reverse the data

# %%
name =["Rajesh","Kowsi","Rajaskar","Seetha","Sampath","Miranah"]

rev=name.reverse()
rev

# %%
name = ["Rajesh","Kowsi","Rajaskar","Seetha","Sampath","Miranah"]

rev = list(reversed(name))
print(rev)
# Out:
# ['Miranah', 'Sampath', 'Seetha', 'Rajaskar', 'Kowsi', 'Rajesh']

# %% [markdown]
# #how to copy data:
#
# create copy of thew list in new variable
#
# Note:
#
# 1. Both variable reference the same list in memory
# 2.  if you use append on copy data it will reflect on original adata also.
# 3.  then if you use pop for removing last element to the data it wont delete what you add newly. it will delete which the original data that last elemt.

# %%
letters=["a","b","c"]
letters
# Out:
# ['a', 'b', 'c']

# %%
letters_copy=letters

# %%
print(f"letters_copy: ,{letters_copy}")
print(f"letters: ,{letters}")
# Out:
# letters_copy: ,['a', 'b', 'c']
# letters: ,['a', 'b', 'c']

# %%
letters.append("x")
letters
# Out:
# ['a', 'b', 'c', 'x', 'x']

# %%
letters.pop()
letters
# Out:
# ['a', 'b']

# %%
#dont use this method.

# %% [markdown]
# #this copy() create seperate list in memory
# Note:
# 1. this technique the whereever use append on that data only get update new val;ue

# %%
letters=["a","b","c"]
letters_copy=letters.copy()

# %%
print(letters_copy)
print(letters)
# Out:
# ['a', 'b', 'c']
# ['a', 'b', 'c']

# %%
letters.append("Y")

# %%
letters
# Out:
# ['a', 'b', 'c', 'Y']

# %%
letters_copy
# Out:
# ['a', 'b', 'c']

# %%
letters_copy.pop()
# Out:
# 'c'

# %%
letters # here only copy data got removed
# Out:
# ['a', 'b', 'c']

# %%
letters.pop()
# Out:
# 'Y'

# %%
matrix=[["a","b"],[]]
matrix
# Out:
# [['a', 'b'], []]

# %%
matrix_copy=matrix.copy()

# %%
matrix_copy
# Out:
# [['a', 'b'], []]

# %%
matrix_copy[1]=["d","e"]#updated

# %%
matrix_copy
# Out:
# [['a', 'b'], ['d', 'e']]

# %%
matrix
# Out:
# [['a', 'b'], []]

# %%
matrix_copy.pop()
# Out:
# ['d', 'e']

# %%
matrix_copy
# Out:
# [['a', 'b']]

# %%
matrix_copy[0].append("x")

# %%
matrix_copy
# Out:
# [['a', 'b', 'x'], 'x']

# %%
matrix
# Out:
# [['a', 'b', 'x']]

# %% [markdown]
# #here data will append on both list this called shalloed copy. so we can use deepcopy() on this. it wont happen shalloed copy

# %% [markdown]
# #DeepCopy()

# %%
import copy

matrix=[["a","b"],["c","d"]]


matrix_copy=copy.deepcopy(matrix)

matrix.pop()
matrix[0].append("z")
print("Original Copy: ", matrix)
print(" Copy: ", matrix_copy)
# Out:
# Original Copy:  [['a', 'b', 'z']]
#  Copy:  [['a', 'b'], ['c', 'd']]

# %%
original=[["a","b"],["c","d"]]

copy1= original

print("Same object? ",original is copy1, "\n")


copy2=original.copy()

print("Same object? ",original is copy2)# its shallowd copy in backend its not same stored
print("Shared list? ",original[0] is copy2[0])

copy3=copy.deepcopy(original)

print("Same object? ",original is copy3)
print("Shared list? ",original[0] is copy3[0])
# Out:
# Same object?  True
#
# Same object?  False
# Shared list?  True
# Same object?  False
# Shared list?  False

# %% [markdown]
# # how to combine list

# %%
letters=[1,2,3,4,5]
numbers=["a","b","c","d"]

comb=letters+numbers
print(comb)
print(comb*2)


#combine 2 list with ,
comb=[letters , numbers]

print(comb)
# Out:
# [1, 2, 3, 4, 5, 'a', 'b', 'c', 'd']
# [1, 2, 3, 4, 5, 'a', 'b', 'c', 'd', 1, 2, 3, 4, 5, 'a', 'b', 'c', 'd']
# [[1, 2, 3, 4, 5], ['a', 'b', 'c', 'd']]

# %% [markdown]
# #Extend() its wont create new list. it expandsthe original one.

# %%
letters=[1,2,3,4,5]
numbers=["a","b","c"]


numbers.extend(letters)

print(letters)
print(numbers)
# Out:
# [1, 2, 3, 4, 5]
# ['a', 'b', 'c', 1, 2, 3, 4, 5]

# %% [markdown]
# #Zip - combine using zip

# %% [markdown]
# #Zip  is used to get data one front the letter and another fromt the numbers then it make new tuple() on inside a list.

# %%
letters=[1,2,3,4,5]
numbers=["a","b","c","d"]

list(zip(letters,numbers))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')]

# %%
Ids=[101,102,103]
Name=["Rajesh","Gokul","Mano","Sounder"]

Comb=Ids+Name

Comb1=[Ids,Name]
AZA
#Ids.extend(Name)

Z=list(zip(Ids,Name))

print(Comb)
print(Comb1)
print(Z)
# Out:
# [101, 102, 103, 'Rajesh', 'Gokul', 'Mano', 'Sounder']
# [[101, 102, 103], ['Rajesh', 'Gokul', 'Mano', 'Sounder']]
# [(101, 'Rajesh'), (102, 'Gokul'), (103, 'Mano')]

# %% [markdown]
# # Iterable and Iterators

# %% [markdown]
# #we are creating containers of items like tuple, int, list, set, disc,  string, bool are All data stored in memory so we need more space.
# Most of the time we dont need that in containers we just need black of subset of few data so now in python in order to overcome this issue we have another type of "iterators"
#
# #iterator are not like containers or book its more like machine its can produced values. its will produce one bye one when we asking

# %% [markdown]
# # Why do we need iterator?

# %% [markdown]
# 1. Save memory
# 2. First is inorder to create a loop. so for loop need iteratort to gothroug  items repeat specific black of code inorder to something
# 3. speed flexible

# %% [markdown]
# #iterator
#
# 1.Iterator is enginbe or machine which is help to iteration.
# 2, we use iteration to transform data
# #iterable
#
# 1.iterable is thing you can loop over like for exa,mple list is iterable because it contains items we can loop data that string values all of data we iterable because something we can loop over. But you have int or big nimber its not iratable.

# %%
letters=["a","b","c"]

for l in letters:
    print(l)
# Out:
# a
# b
# c

# %%
numbers=564324865342

for n in numbers:
    print(n)#its not a iterable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 numbers=564324865342
# ----> 3 for n in numbers:
#       4     print(n)#its not a iterable
#
# TypeError: 'int' object is not iterable

# %%
letters=["a","b","c"]

for l in letters:
    print(l.upper())
# Out:
# A
# B
# C

# %%
#Task - Stored the transformed data in new list

letters=["a","b","c"]
New_list=[]

for l in letters:
    New_list.append(l.upper())
    print(New_list)
# Out:
# ['A']
# ['A', 'B']
# ['A', 'B', 'C']

# %% [markdown]
# #iterator - Enumerator, reversed, zip

# %% [markdown]
# Enumarator - actually for loop give only value but enumarator is give the values index position.
#
# Enumerator Use Case - Find the exact position of the bad data in the ist.

# %%
letters=["a","b","c"]#iterable
print(enumerate(letters))

#<enumerate object at 0x000001A9FEF5F010>---iterator

letters=["a","b","c"]#iterable
print(list(enumerate(letters)))
# Out:
# ...
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %% [markdown]
# #if you dont want to start index number 0 the use start=1 funtion on ablove.

# %%
letters=["a","b","c"]#iterable
print(list(enumerate(letters ,start=1)))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
letters=["a","b","c"]

for index,i in enumerate(letters):
    print(index,i)
# Out:
# 0 a
# 1 b
# 2 c

# %% [markdown]
# Reversed - Return an iterator that flips the data

# %%
letters=["a","b","c"]
#print(list(reversed(letters)))

for i in reversed(letters):
    print(i)
# Out:
# c
# b
# a

# %% [markdown]
# Zip- combine two or more list to pair.[tuples]

# %%
letters=["a","b","c"]
numbers=[1,2,3]

#list(zip(letters,numbers))

for l,n in zip(letters,numbers):
    print(l, n)
# Out:
# a 1
# b 2
# c 3

# %% [markdown]
# Map - Map is so fast, clean way to so data transformtaion.

# %%
#Task - Make all values to upper
letters=["a","b","c"]

print(list(map(str.upper,letters)))
# Out:
# ['A', 'B', 'C']

# %%
#Task -  covert str to int

numbers=["1","2","3"]

print(list(map(int,numbers)))
# Out:
# [1, 2, 3]

# %%
#Task - Clean all extra spaces

letters=["a   ","   b","c  "]

#list(map(str.strip,letters))

for i in map(str.strip,letters):
    print(i)
# Out:
# a
# b
# c

# %% [markdown]
# Filter - filtering the data

# %%
#Task - clean the list by unwanted space,none, bad data

letters=["a","b",None,"c",""]
print(list(filter(None,letters)))


letters=["a","b",None,"c",""]
print(list(filter(bool,letters)))
# Out:
# ['a', 'b', 'c']
# ['a', 'b', 'c']

# %%
#Task - get only albhapatical values

name=["Rajesh","354","Nokia","4554"]

#list(filter(str.isalpha,name))

for i in list(filter(str.isalpha,name)):
    print(i)
# Out:
# Rajesh
# Nokia

# %% [markdown]
# # Lambda

# %%
multiple=lambda x:x*2
print(multiple(2))
# Out:
# 4

# %%
multiple=lambda a,b: a*b
print(multiple(2,2))
# Out:
# 4

# %%
check= lambda i: i in "Rajesh"
print(check("j"))

print(check("k"))
# Out:
# True
# False

# %%
Amount=["$12.50","$56.67","$10.00"]

B=list(map(lambda A : float(A.replace("$","")),Amount))
B
# Out:
# [12.5, 56.67, 10.0]

# %%
Amount=["$12.50","$56.67","$10.00"]
values=[]

for A in Amount:
    values.append(float(A.replace("$","")))
    print(values)
# Out:
# [12.5]
# [12.5, 56.67]
# [12.5, 56.67, 10.0]

# %%
prices=[100,80,120,140]

x=list(filter(lambda p : p >100,prices))
print(x)
# Out:
# [120, 140]

# %%
prices=[100,80,120,140]

for i in prices:
    if i >100:
        
        print(i)
# Out:
# 120
# 140

# %%
Name=[["Maria", 90],["Rajesh",100],["Mama",40]]

print(list(filter(lambda row:row[1]>90,Name)))
# Out:
# [['Rajesh', 100]]

# %% [markdown]
# #find starting position is "M"

# %%
Name=[["Maria", 90],["Rajesh",100],["Mama",40]]

list(filter(lambda a: a[0].startswith("M"),Name))
# Out:
# [['Maria', 90], ['Mama', 40]]

# %% [markdown]
# # list Comprehension

# %% [markdown]
# list comprehension is doing 3 things in one concept which is data transformation, loop, filter you data.
#
# if you have [10,30,30,40] first then go to loop and itll go to the filter if the condition is satisfied then go to the data transformation .

# %%
# Normalize the domain into standard format

domins=["google.com","WWW.openai.com","music","Amazon.com"]

#clean=[
       #data transformation
       #loop
       #filtering
#]
clean = [
    d.lower().replace("www.", "")
    for d in domins
    if "."   in d
]

print(clean)
# Out:
# ['google.com', 'openai.com', 'amazon.com']

# %% [markdown]
# # List operator

# %% [markdown]
# 1. indxing
# 2. slicing
# 3. max()
# 4. min()
# 5. sum()
# 6. len()
# 7. all()
# 8. any()
# 9. A.count("a")
# 10. A.index("a")
# 11. in
# 12. append
# 13. insert
# 14. clear
# 15. remove
# 16. pop
# 17. sort()
# 18. reverse()
# 19. a=b --copy
# 20. b=a.copy
# 21. deepcopy()
# 22. a+b
# 23. .extend
# 24. zip
# 25. ernumerate
# 26. map
# 27. strip
# 28. filter
# 29. comprehension

# %% [markdown]
# List funtion ?
#
# 1. List are Ordered.(machine remember the order)
# 2. we can stored dulicate here.
# 3. list are indexed. its default stored as 0.
# 4. list are mutable. we can make sort, update, removing, insert.

# %% [markdown]
# If you or someone change your code on your list project you may lose the connection to database and everything gonna fail. so we use tupls
